# %% [markdown]
# ## Demo

# %%
import joblib
import gradio as gr
import pandas as pd

# %%
model = joblib.load('heart_attack_prediction_model.joblib')

# %%
model
# Out:
# RandomForestClassifier(criterion='entropy', max_depth=5, min_samples_split=3)

# %%
# def predict_heart_attack(
#     age,
#     # gender,
#     # region,
#     # income_level,
#     hypertension,
#     diabetes,
#     cholesterol_level,
#     # obesity,
#     # waist_circumference,
#     # family_history,
#     smoking_status,
#     # alcohol_consumption,
#     # physical_activity,
#     # dietary_habits,
#     air_pollution_exposure,
#     # stress_level,
#     # sleep_hours,
#     # blood_pressure_systolic,
#     # blood_pressure_diastolic,
#     fasting_blood_sugar,
#     # cholesterol_hdl,
#     # cholesterol_ldl,
#     # triglycerides,
#     # EKG_results,
#     previous_heart_disease,
#     # medication_usage,
#     # participated_in_free_screening,
#     # heart_attack
# ):
#     previous_heart_disease_map = {'Yes':1, 'No':0}
#     hypertension_map = {'Yes':1, 'No':0}
#     diabetes_map = {'Yes':1, 'No':0}
#     smoking_status_map = {'Never': 'Never', 'Past':'Past', 'Current':'Current'}
#     air_pollution_exposure_map = {'Low': 'Low', 'Moderate': 'Moderate', 'High': 'High'}

#     input_data = pd.DataFrame({
#         'previous_heart_disease': [previous_heart_disease_map[previous_heart_disease]],
#         'hypertension': [hypertension_map[hypertension]],
#         'diabetes': [diabetes_map[diabetes]],
#         'smoking_status': [smoking_status_map[smoking_status]],
#         'air_pollution_exposure': [air_pollution_exposure_map[air_pollution_exposure]],
#         'age': age,
#         'cholesterol_level': cholesterol_level,
#         'fasting_blood_sugar': fasting_blood_sugar,
#     })
#     prediction = model.predict(input_data)
#     return f"{int(prediction[0])} out of 1 (1 = Heart Attack, 0 = No Heart Attack)"

# with gr.Blocks(title='Heart Attack Prediction in Indonesia') as demo:
#     gr.Markdown("# Heart Attack Prediction in Indonesia")
#     with gr.Row():
#         with gr.Column():
#             previous_heart_disease = gr.Radio(['Yes', 'No'], label='Previous Heart Disease')
#             hypertension = gr.Radio(['Yes', 'No'], label='Hypertension')
#             diabetes = gr.Radio(['Yes', 'No'], label='Diabetes')
#             smoking_status = gr.Radio(['Never', 'Past', 'Current'], label='Smoking Status')
#             air_pollution_exposure = gr.Radio(['Low', 'Moderate', 'High'], label='Air Pollution Exposure')

#             age = gr.Slider(25, 90, step=0.5, label='Age (minimum: 25)')
#             cholesterol_level = gr.Slider(100, 318, step=0.1, label='Cholesterol Level (minimum: 100)')
#             fasting_blood_sugar = gr.Slider(70, 193, step=0.1, label='Fasting Blood Sugar (minimum: 70)')
#             predict_button = gr.Button("Predict Heart Attack")
#             prediction_output = gr.Textbox(label='Prediction Output', value='Click predict to see the result')
#         predict_button.click(
#             fn = predict_heart_attack,
#             inputs = [
#                 previous_heart_disease, 
#                 hypertension, diabetes, 
#                 smoking_status, 
#                 air_pollution_exposure,age, 
#                 cholesterol_level,
#                 fasting_blood_sugar
#                 ],
#             outputs = prediction_output
#         )
# if __name__ == "__main__":
#     demo.launch()

# %%
import pandas as pd
import gradio as gr
# from your_model_file import load_model  # You'll need to load your actual model

# Load your model (example - replace with your actual model loading code)
# model = load_model()

def predict_heart_attack(
    age,
    hypertension,
    diabetes,
    cholesterol_level,
    smoking_status,
    air_pollution_exposure,
    fasting_blood_sugar,
    previous_heart_disease
):
    # Convert categorical inputs to numerical
    input_data = pd.DataFrame({
        'previous_heart_disease': [1 if previous_heart_disease == 'Yes' else 0],
        'hypertension': [1 if hypertension == 'Yes' else 0],
        'diabetes': [1 if diabetes == 'Yes' else 0],
        'smoking_status': [smoking_status],  # Assuming model handles these categories
        'air_pollution_exposure': [air_pollution_exposure],  # Assuming model handles these
        'age': [age],
        'cholesterol_level': [cholesterol_level],
        'fasting_blood_sugar': [fasting_blood_sugar],
    })
    
    # Make prediction (ensure your model is loaded)
    prediction = model.predict(input_data)
    
    # Return more user-friendly output
    result = "Heart Attack" if prediction[0] == 1 else "No Heart Attack"
    return f"Prediction: {result} (Probability: {prediction[0]:.2f})"

with gr.Blocks(title='Heart Attack Prediction in Indonesia') as demo:
    gr.Markdown("# Heart Attack Prediction in Indonesia")
    with gr.Row():
        with gr.Column():
            previous_heart_disease = gr.Radio(['Yes', 'No'], label='Previous Heart Disease')
            hypertension = gr.Radio(['Yes', 'No'], label='Hypertension')
            diabetes = gr.Radio(['Yes', 'No'], label='Diabetes')
            smoking_status = gr.Radio(['Never', 'Past', 'Current'], label='Smoking Status')
            air_pollution_exposure = gr.Radio(['Low', 'Moderate', 'High'], label='Air Pollution Exposure')

            age = gr.Slider(25, 90, step=0.5, label='Age (minimum: 25)')
            cholesterol_level = gr.Slider(100, 318, step=0.1, label='Cholesterol Level (minimum: 100)')
            fasting_blood_sugar = gr.Slider(70, 193, step=0.1, label='Fasting Blood Sugar (minimum: 70)')
            
            predict_button = gr.Button("Predict Heart Attack")
            prediction_output = gr.Textbox(label='Prediction Result', value='Click predict to see the result')
            
        predict_button.click(
            fn=predict_heart_attack,
            inputs=[
                age,
                hypertension, 
                diabetes, 
                cholesterol_level,
                smoking_status, 
                air_pollution_exposure,
                fasting_blood_sugar,
                previous_heart_disease
            ],
            outputs=prediction_output
        )

if __name__ == "__main__":
    demo.launch()
# Out:
# * Running on local URL:  http://127.0.0.1:7862
#
# To create a public link, set `share=True` in `launch()`.
# <div><iframe src="http://127.0.0.1:7862/" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
# c:\Users\Keith\anaconda3\Lib\site-packages\sklearn\base.py:486: UserWarning: X has feature names, but RandomForestClassifier was fitted without feature names
#   warnings.warn(
# Traceback (most recent call last):
#   File "c:\Users\Keith\anaconda3\Lib\site-packages\gradio\queueing.py", line 625, in process_events
#     response = await route_utils.call_process_api(
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Keith\anaconda3\Lib\site-packages\gradio\route_utils.py", line 322, in call_process_api
#     output = await app.get_blocks().process_api(
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ...
